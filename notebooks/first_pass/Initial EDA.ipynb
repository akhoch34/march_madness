# %%
import sys,os
folder_name="march_madness"
BASE_DIR=os.path.abspath(".").split(folder_name)[0]+folder_name
DATA_ROOT=os.path.join(BASE_DIR,"data")
#todo setup shared utilities folder
sys.path.insert(0, DATA_ROOT)

# %%
import pandas as pd
pd.options.display.max_columns=999
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
regular_season_results_df=pd.read_csv(DATA_ROOT+"/DataFiles/RegularSeasonDetailedResults.csv")
regular_season_results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LFGM  LFGA  \
# 0      3     14    11    18   14   24    13   23     7     1   22    22    53
# 1      8     20    10    19   15   28    16   13     4     4   18    24    67
# 2      8     18    17    29   17   26    15   10     5     2   25    22    73
# 3      3      9    17    31    6   19    11   12    14     2   18    18    49
# 4      6     14    11    13   17   22    12   14     4     4   20    24    62
#
#    LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0      2     10    16    22   10   22     8   18     9     2   20
# 1      6     24     9    20   20   25     7   12     8     6   16
# 2      3     26    14    23   31   22     9   12     2     5   23
# 3      6     22     8    15   17   20     9   19     4     3   23
# 4      6     16    17    27   21   15    12   10     7     1   14

# %%
teams=pd.read_csv(DATA_ROOT+"/DataFiles/Teams.csv")
team_conferences=pd.read_csv(DATA_ROOT+"/DataFiles/TeamConferences.csv")#contains season

# %%
#try skellam?
regular_season_results_df[['WScore']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB8EE84978>]],
#       dtype=object)

# %%
regular_season_results_df.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF'],
#       dtype='object')

# %%
import featuretools as ft

# %%
es_mc = ft.demo.load_mock_customer(return_entityset=True, random_seed=0)
es_mc['transactions'].df.head()
# Out:
#      transaction_id  session_id    transaction_time  amount product_id
# 298             298           1 2014-01-01 00:00:00  127.64          5
# 2                 2           1 2014-01-01 00:01:05  109.48          2
# 308             308           1 2014-01-01 00:02:10   95.06          3
# 116             116           1 2014-01-01 00:03:15   78.92          4
# 371             371           1 2014-01-01 00:04:20   31.54          3

# %%
es_mc
# Out:
# Entityset: transactions
#   Entities:
#     transactions [Rows: 500, Columns: 5]
#     products [Rows: 5, Columns: 2]
#     sessions [Rows: 35, Columns: 4]
#     customers [Rows: 5, Columns: 4]
#   Relationships:
#     transactions.product_id -> products.product_id
#     transactions.session_id -> sessions.session_id
#     sessions.customer_id -> customers.customer_id

# %%
es_mc.plot()

# %%
fm, features = ft.dfs(entityset=es_mc,
                     target_entity="customers"
                     )

# %%
features
# Out:
# [<Feature: zip_code>,
#  <Feature: COUNT(sessions)>,
#  <Feature: NUM_UNIQUE(sessions.device)>,
#  <Feature: MODE(sessions.device)>,
#  <Feature: SUM(transactions.amount)>,
#  <Feature: STD(transactions.amount)>,
#  <Feature: MAX(transactions.amount)>,
#  <Feature: SKEW(transactions.amount)>,
#  <Feature: MIN(transactions.amount)>,
#  <Feature: MEAN(transactions.amount)>,
#  <Feature: COUNT(transactions)>,
#  <Feature: NUM_UNIQUE(transactions.product_id)>,
#  <Feature: MODE(transactions.product_id)>,
#  <Feature: DAY(join_date)>,
#  <Feature: DAY(date_of_birth)>,
#  <Feature: YEAR(join_date)>,
#  <Feature: YEAR(date_of_birth)>,
#  <Feature: MONTH(join_date)>,
#  <Feature: MONTH(date_of_birth)>,
#  <Feature: WEEKDAY(join_date)>,
#  <Feature: WEEKDAY(date_of_birth)>,
#  <Feature: SUM(sessions.STD(transactions.amount))>,
#  <Feature: SUM(sessions.MAX(transactions.amount))>,
#  <Feature: SUM(sessions.SKEW(transactions.amount))>,
#  <Feature: SUM(sessions.MIN(transactions.amount))>,
#  <Feature: SUM(sessions.MEAN(transactions.amount))>,
#  <Feature: SUM(sessions.NUM_UNIQUE(transactions.product_id))>,
#  <Feature: STD(sessions.SUM(transactions.amount))>,
#  <Feature: STD(sessions.MAX(transactions.amount))>,
#  <Feature: STD(sessions.SKEW(transactions.amount))>,
#  <Feature: STD(sessions.MIN(transactions.amount))>,
#  <Feature: STD(sessions.MEAN(transactions.amount))>,
#  <Feature: STD(sessions.COUNT(transactions))>,
#  <Feature: STD(sessions.NUM_UNIQUE(transactions.product_id))>,
#  <Feature: MAX(sessions.SUM(transactions.amount))>,
#  <Feature: MAX(sessions.STD(transactions.amount))>,
#  <Feature: MAX(sessions.SKEW(transactions.amount))>,
#  <Feature: MAX(sessions.MIN(transactions.amount))>,
#  <Feature: MAX(sessions.MEAN(transactions.amount))>,
#  <Feature: MAX(sessions.COUNT(transactions))>,
#  <Feature: MAX(sessions.NUM_UNIQUE(transactions.product_id))>,
#  <Feature: SKEW(sessions.SUM(transactions.amount))>,
#  <Feature: SKEW(sessions.STD(transactions.amount))>,
#  <Feature: SKEW(sessions.MAX(transactions.amount))>,
#  <Feature: SKEW(sessions.MIN(transactions.amount))>,
#  <Feature: SKEW(sessions.MEAN(transactions.amount))>,
#  <Feature: SKEW(sessions.COUNT(transactions))>,
#  <Feature: SKEW(sessions.NUM_UNIQUE(transactions.product_id))>,
#  <Feature: MIN(sessions.SUM(transactions.amount))>,
#  <Feature: MIN(sessions.STD(transactions.amount))>,
#  <Feature: MIN(sessions.MAX(transactions.amount))>,
#  <Feature: MIN(sessions.SKEW(transactions.amount))>,
#  <Feature: MIN(sessions.MEAN(transactions.amount))>,
#  <Feature: MIN(sessions.COUNT(transactions))>,
#  <Feature: MIN(sessions.NUM_UNIQUE(transactions.product_id))>,
#  <Feature: MEAN(sessions.SUM(transactions.amount))>,
#  <Feature: MEAN(sessions.STD(transactions.amount))>,
#  <Feature: MEAN(sessions.MAX(transactions.amount))>,
#  <Feature: MEAN(sessions.SKEW(transactions.amount))>,
#  <Feature: MEAN(sessions.MIN(transactions.amount))>,
#  <Feature: MEAN(sessions.MEAN(transactions.amount))>,
#  <Feature: MEAN(sessions.COUNT(transactions))>,
#  <Feature: MEAN(sessions.NUM_UNIQUE(transactions.product_id))>,
#  <Feature: NUM_UNIQUE(sessions.MODE(transactions.product_id))>,
#  <Feature: NUM_UNIQUE(sessions.DAY(session_start))>,
#  <Feature: NUM_UNIQUE(sessions.YEAR(session_start))>,
#  <Feature: NUM_UNIQUE(sessions.MONTH(session_start))>,
#  <Feature: NUM_UNIQUE(sessions.WEEKDAY(session_start))>,
#  <Feature: MODE(sessions.MODE(transactions.product_id))>,
#  <Feature: MODE(sessions.DAY(session_start))>,
#  <Feature: MODE(sessions.YEAR(session_start))>,
#  <Feature: MODE(sessions.MONTH(session_start))>,
#  <Feature: MODE(sessions.WEEKDAY(session_start))>]

# %%
fm
# Out:
#             zip_code  COUNT(sessions)  NUM_UNIQUE(sessions.device)  \
# customer_id
# 1              60091                8                            3
# 2              13244                7                            3
# 3              13244                6                            3
# 4              60091                8                            3
# 5              60091                6                            3
#
#             MODE(sessions.device)  SUM(transactions.amount)  \
# customer_id
# 1                          mobile                   9025.62
# 2                         desktop                   7200.28
# 3                         desktop                   6236.62
# 4                          mobile                   8727.68
# 5                          mobile                   6349.66
#
#              STD(transactions.amount)  MAX(transactions.amount)  \
# customer_id
# 1                           40.442059                    139.43
# 2                           37.705178                    146.81
# 3                           43.683296                    149.15
# 4                           45.068765                    149.95
# 5                           44.095630                    149.02
#
#              SKEW(transactions.amount)  MIN(transactions.amount)  \
# customer_id
# 1                             0.019698                      5.81
# 2                             0.098259                      8.73
# 3                             0.418230                      5.89
# 4                            -0.036348                      5.73
# 5                            -0.025941                      7.55
#
#              MEAN(transactions.amount)  COUNT(transactions)  \
# customer_id
# 1                            71.631905                  126
# 2                            77.422366                   93
# 3                            67.060430                   93
# 4                            80.070459                  109
# 5                            80.375443                   79
#
#              NUM_UNIQUE(transactions.product_id)  \
# customer_id
# 1                                              5
# 2                                              5
# 3                                              5
# 4                                              5
# 5                                              5
#
#              MODE(transactions.product_id)  DAY(join_date)  \
# customer_id
# 1                                        4              17
# 2                                        4              15
# 3                                        1              13
# 4                                        2               8
# 5                                        5              17
#
#              DAY(date_of_birth)  YEAR(join_date)  YEAR(date_of_birth)  \
# customer_id
# 1                            18             2011                 1994
# 2                            18             2012                 1986
# 3                            21             2011                 2003
# 4                            15             2011                 2006
# 5                            28             2010                 1984
#
#              MONTH(join_date)  MONTH(date_of_birth)  WEEKDAY(join_date)  \
# customer_id
# 1                           4                     7                   6
# 2                           4                     8                   6
# 3                           8                    11                   5
# 4                           4                     8                   4
# 5                           7                     7                   5
#
#              WEEKDAY(date_of_birth)  SUM(sessions.STD(transactions.amount))  \
# customer_id
# 1                                 0                              312.745952
# 2                                 0                              258.700528
# 3                                 4                              257.299895
# 4                                 1                              356.125829
# 5                                 5                              259.873954
#
#              SUM(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                           1057.97
# 2                                            931.63
# 3                                            847.63
# 4                                           1157.99
# 5                                            839.76
#
#              SUM(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                          -0.476122
# 2                                          -0.277640
# 3                                           2.286086
# 4                                           0.002764
# 5                                           0.014384
#
#              SUM(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                             78.59
# 2                                            154.60
# 3                                             66.21
# 4                                            131.51
# 5                                             86.49
#
#              SUM(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                         582.193117
# 2                                         548.905851
# 3                                         405.237462
# 4                                         649.657515
# 5                                         472.231119
#
#              SUM(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                           40
# 2                                                           35
# 3                                                           29
# 4                                                           37
# 5                                                           30
#
#              STD(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                        279.510713
# 2                                        251.609234
# 3                                        219.021420
# 4                                        235.992478
# 5                                        402.775486
#
#              STD(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                          7.322191
# 2                                         17.221593
# 3                                         10.724241
# 4                                          3.514421
# 5                                          7.928001
#
#              STD(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                           0.589386
# 2                                           0.509798
# 3                                           0.429374
# 4                                           0.387884
# 5                                           0.415426
#
#              STD(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                          6.954507
# 2                                         15.874374
# 3                                          5.424407
# 4                                         16.960575
# 5                                          4.961414
#
#              STD(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                          13.759314
# 2                                          11.477071
# 3                                          11.174282
# 4                                          13.027258
# 5                                          11.007471
#
#              STD(sessions.COUNT(transactions))  \
# customer_id
# 1                                     4.062019
# 2                                     3.450328
# 3                                     2.428992
# 4                                     3.335416
# 5                                     3.600926
#
#              STD(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                     0.000000
# 2                                                     0.000000
# 3                                                     0.408248
# 4                                                     0.517549
# 5                                                     0.000000
#
#              MAX(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                           1613.93
# 2                                           1320.64
# 3                                           1477.97
# 4                                           1351.46
# 5                                           1700.67
#
#              MAX(sessions.STD(transactions.amount))  \
# customer_id
# 1                                         46.905665
# 2                                         47.935920
# 3                                         50.110120
# 4                                         54.293903
# 5                                         51.149250
#
#              MAX(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                           0.640252
# 2                                           0.755711
# 3                                           0.854976
# 4                                           0.382868
# 5                                           0.602209
#
#              MAX(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                             26.36
# 2                                             56.46
# 3                                             20.06
# 4                                             54.83
# 5                                             20.65
#
#              MAX(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                          88.755625
# 2                                          96.581000
# 3                                          82.109444
# 4                                         110.450000
# 5                                          94.481667
#
#              MAX(sessions.COUNT(transactions))  \
# customer_id
# 1                                           25
# 2                                           18
# 3                                           18
# 4                                           18
# 5                                           18
#
#              MAX(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                            5
# 2                                                            5
# 3                                                            5
# 4                                                            5
# 5                                                            5
#
#              SKEW(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                           0.778170
# 2                                          -0.440929
# 3                                           2.246479
# 4                                          -0.391805
# 5                                           0.472342
#
#              SKEW(sessions.STD(transactions.amount))  \
# customer_id
# 1                                          -0.312355
# 2                                           0.013087
# 3                                          -0.245703
# 4                                          -1.065663
# 5                                           0.204548
#
#              SKEW(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                          -0.780493
# 2                                          -1.539467
# 3                                          -0.941078
# 4                                           0.027256
# 5                                          -0.333796
#
#              SKEW(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                           2.440005
# 2                                           2.154929
# 3                                           1.000771
# 4                                           2.103510
# 5                                          -0.470410
#
#              SKEW(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                           -0.424949
# 2                                            0.235296
# 3                                            0.678544
# 4                                            1.980948
# 5                                            0.335175
#
#              SKEW(sessions.COUNT(transactions))  \
# customer_id
# 1                                      1.946018
# 2                                     -0.303276
# 3                                     -1.507217
# 4                                      0.282488
# 5                                     -0.317685
#
#              SKEW(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                     0.000000
# 2                                                     0.000000
# 3                                                    -2.449490
# 4                                                    -0.644061
# 5                                                     0.000000
#
#              MIN(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                            809.97
# 2                                            634.84
# 3                                            889.21
# 4                                            771.68
# 5                                            543.18
#
#              MIN(sessions.STD(transactions.amount))  \
# customer_id
# 1                                         30.450261
# 2                                         27.839228
# 3                                         35.704680
# 4                                         29.026424
# 5                                         36.734681
#
#              MIN(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                            118.90
# 2                                            100.04
# 3                                            126.74
# 4                                            139.20
# 5                                            128.51
#
#              MIN(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                          -1.038434
# 2                                          -0.763603
# 3                                          -0.289466
# 4                                          -0.711744
# 5                                          -0.539060
#
#              MIN(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                          50.623125
# 2                                          61.910000
# 3                                          55.579412
# 4                                          70.638182
# 5                                          66.666667
#
#              MIN(sessions.COUNT(transactions))  \
# customer_id
# 1                                           12
# 2                                            8
# 3                                           11
# 4                                           10
# 5                                            8
#
#              MIN(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                            5
# 2                                                            5
# 3                                                            4
# 4                                                            4
# 5                                                            5
#
#              MEAN(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                        1128.202500
# 2                                        1028.611429
# 3                                        1039.436667
# 4                                        1090.960000
# 5                                        1058.276667
#
#              MEAN(sessions.STD(transactions.amount))  \
# customer_id
# 1                                          39.093244
# 2                                          36.957218
# 3                                          42.883316
# 4                                          44.515729
# 5                                          43.312326
#
#              MEAN(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                         132.246250
# 2                                         133.090000
# 3                                         141.271667
# 4                                         144.748750
# 5                                         139.960000
#
#              MEAN(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                           -0.059515
# 2                                           -0.039663
# 3                                            0.381014
# 4                                            0.000346
# 5                                            0.002397
#
#              MEAN(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                           9.823750
# 2                                          22.085714
# 3                                          11.035000
# 4                                          16.438750
# 5                                          14.415000
#
#              MEAN(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                           72.774140
# 2                                           78.415122
# 3                                           67.539577
# 4                                           81.207189
# 5                                           78.705187
#
#              MEAN(sessions.COUNT(transactions))  \
# customer_id
# 1                                     15.750000
# 2                                     13.285714
# 3                                     15.500000
# 4                                     13.625000
# 5                                     13.166667
#
#              MEAN(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                     5.000000
# 2                                                     5.000000
# 3                                                     4.833333
# 4                                                     4.625000
# 5                                                     5.000000
#
#              NUM_UNIQUE(sessions.MODE(transactions.product_id))  \
# customer_id
# 1                                                            4
# 2                                                            4
# 3                                                            4
# 4                                                            5
# 5                                                            5
#
#              NUM_UNIQUE(sessions.DAY(session_start))  \
# customer_id
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#              NUM_UNIQUE(sessions.YEAR(session_start))  \
# customer_id
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                   1
# 5                                                   1
#
#              NUM_UNIQUE(sessions.MONTH(session_start))  \
# customer_id
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# 5                                                    1
#
#              NUM_UNIQUE(sessions.WEEKDAY(session_start))  \
# customer_id
# 1                                                      1
# 2                                                      1
# 3                                                      1
# 4                                                      1
# 5                                                      1
#
#              MODE(sessions.MODE(transactions.product_id))  \
# customer_id
# 1                                                       4
# 2                                                       3
# 3                                                       1
# 4                                                       1
# 5                                                       3
#
#              MODE(sessions.DAY(session_start))  \
# customer_id
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
# 5                                            1
#
#              MODE(sessions.YEAR(session_start))  \
# customer_id
# 1                                          2014
# 2                                          2014
# 3                                          2014
# 4                                          2014
# 5                                          2014
#
#              MODE(sessions.MONTH(session_start))  \
# customer_id
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# 5                                              1
#
#              MODE(sessions.WEEKDAY(session_start))
# customer_id
# 1                                                2
# 2                                                2
# 3                                                2
# 4                                                2
# 5                                                2

# %% [markdown]
# # Naive Model to Test Submission File

# %%
from itertools import combinations

# %%
tourney_seeds=pd.read_csv(DATA_ROOT+"/DataFiles/NCAATourneySeeds.csv")
possible_games_df=pd.DataFrame()
for season, seeds in tourney_seeds.groupby("Season"):
    possible_games=list(combinations(tourney_seeds[tourney_seeds['Season']==season]['TeamID'],2))
    df=pd.DataFrame(possible_games)
    df['Season']=season
    possible_games_df=possible_games_df.append(df)
possible_games_df['ID']=possible_games_df.apply(lambda row: "%s_%s_%s"%(row['Season'],min([row[0],row[1]]),max([row[0],row[1]])), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eba2f20c35a2> in <module>
# ----> 1 tourney_seeds=pd.read_csv(DATA_ROOT+"/DataFiles/NCAATourneySeeds.csv")
#       2 possible_games_df=pd.DataFrame()
#       3 for season, seeds in tourney_seeds.groupby("Season"):
#       4     possible_games=list(combinations(tourney_seeds[tourney_seeds['Season']==season]['TeamID'],2))
#       5     df=pd.DataFrame(possible_games)
#
# NameError: name 'pd' is not defined

# %%
possible_games_df['Pred']=0.5

# %%
submission=possible_games_df[possible_games_df['Season']>=2014][['ID','Pred']]
submission.to_csv("submission.csv",index=False)

# %%
len(submission)
# Out:
# 11390

# %%
#submission most have id with team ID's ordered from lowest to highest

# %% [markdown]
# # Initial FeatureSet Integration
# 1 entity (regular season games)
# then try with conferences using a team_id and season_link (can it be compound key?)

# %%
#using https://towardsdatascience.com/automated-feature-engineering-for-predictive-modeling-d8c9fa4e478b as a starting point
#interface looks a little old so I am using the current FT docs too
from sklearn.linear_model import LogisticRegression

# %%
regular_season_results_df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LFGM  LFGA  \
# 0      3     14    11    18   14   24    13   23     7     1   22    22    53
# 1      8     20    10    19   15   28    16   13     4     4   18    24    67
# 2      8     18    17    29   17   26    15   10     5     2   25    22    73
# 3      3      9    17    31    6   19    11   12    14     2   18    18    49
# 4      6     14    11    13   17   22    12   14     4     4   20    24    62
#
#    LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF  \
# 0      2     10    16    22   10   22     8   18     9     2   20
# 1      6     24     9    20   20   25     7   12     8     6   16
# 2      3     26    14    23   31   22     9   12     2     5   23
# 3      6     22     8    15   17   20     9   19     4     3   23
# 4      6     16    17    27   21   15    12   10     7     1   14
#
#         game_index game_datetime
# 0  200310_11041328    2003-01-11
# 1  200310_12721393    2003-01-11
# 2  200311_12661437    2003-01-12
# 3  200311_12961457    2003-01-12
# 4  200311_14001208    2003-01-12

# %%
import datetime
def get_game_index(row):
    return "%s%s_%s%s"%(row['Season'],row['DayNum'],row['WTeamID'],row['LTeamID'])


def get_game_daytime(row):
    #not an acutal "day". This uses Season and DayNum without a first day to index the day_num
    
    base_day=datetime.datetime(row['Season'],1,1)
    game_day=base_day+datetime.timedelta(days=row['DayNum'])
    return game_day
    
regular_season_results_df['game_index']=regular_season_results_df.apply(get_game_index, axis=1)
regular_season_results_df['game_datetime']=regular_season_results_df.apply(get_game_daytime, axis=1)

# %%
#todo create dynamic id builder
def get_team_season_id(row):
    return "%s_%s"%(row['Season'],row['TeamID'])
team_conferences['team_season_id']=team_conferences.apply(get_team_season_id, axis=1)

# %%
#TODO need to split results into team_game_logs

# %%
regular_season_results_df.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'game_index', 'game_datetime'],
#       dtype='object')

# %%
game=regular_season_results_df.iloc[0]
def get_team_game_log(results_df,winner=True):
    team_game_log=regular_season_results_df.copy()
    prefixes=["team_","opp_"]
    if not winner:
        prefixes=["opp_","team_"]
    rename_dict={}
    for col in regular_season_results_df.columns:
        if col=="WLoc":
            continue
        elif col.startswith("W"):
            rename_dict[col]=prefixes[0]+col[1:]
        elif col.startswith("L") and col not in ["Loc"]:
            rename_dict[col]=prefixes[1]+col[1:]
    team_game_log=team_game_log.rename(columns=rename_dict)
    return team_game_log
winner_games=get_team_game_log(regular_season_results_df, winner=True)
loser_games=get_team_game_log(regular_season_results_df, winner=False)
team_game_log=pd.concat([winner_games,loser_games],sort=False)
team_game_log=team_game_log.sort_values(by=["Season","DayNum","game_index"])
team_game_log['team_margin']=team_game_log['team_Score']-team_game_log['opp_Score']
team_game_log['team_won']=team_game_log['team_margin']>0
#teams can't tie in basketball, above code assumes that
assert(len(team_game_log[team_game_log['team_margin']==0])==0)

# %%
def get_game_loc(row):
    if row['team_won']:
        return row['WLoc']
    else:
        if row['WLoc']=='H':
            return 'A'
        elif row['WLoc']=='A':
            return 'H'
        else:
            return row['WLoc']
team_game_log['game_loc']=team_game_log.apply(get_game_loc,axis=1)
del team_game_log['WLoc']
def get_team_game_index(row):
    return "%s%s_%s_%s"%(row['Season'],row['DayNum'],row['team_TeamID'],row['opp_TeamID'])
team_game_log['team_game_index']=team_game_log.apply(get_team_game_index, axis=1)

def get_team_season_index_from_games(row):
    return "%s_%s"%(row['Season'],row['team_TeamID'])
team_game_log['team_season_id']=team_game_log.apply(get_team_season_index_from_games, axis=1)

# %%
season=2016
es = ft.EntitySet()
#compound key index?
es = es.entity_from_dataframe(entity_id="team_game_log",
                             dataframe=team_game_log[team_game_log['Season']==season].drop(["game_index"],axis=1),
                              index="team_game_index",
                              time_index="game_datetime",
                              
                             )


# es = es.entity_from_dataframe(entity_id="team_conferences",
#                              dataframe=team_conferences[team_conferences['Season']==season],
#                               index="team_season_id"
#                              )
# es = es.add_relationship(
#     ft.Relationship(
#                     es['team_conferences']['team_season_id'], 
#                     es['team_game_log']['team_season_id']
#                    )
# )

# %%
es['team_game_log']
# Out:
# Entity: team_game_log
#   Variables:
#     team_game_index (dtype: index)
#     Season (dtype: numeric)
#     DayNum (dtype: numeric)
#     team_TeamID (dtype: numeric)
#     team_Score (dtype: numeric)
#     opp_TeamID (dtype: numeric)
#     opp_Score (dtype: numeric)
#     NumOT (dtype: numeric)
#     team_FGM (dtype: numeric)
#     team_FGA (dtype: numeric)
#     team_FGM3 (dtype: numeric)
#     team_FGA3 (dtype: numeric)
#     team_FTM (dtype: numeric)
#     team_FTA (dtype: numeric)
#     team_OR (dtype: numeric)
#     team_DR (dtype: numeric)
#     team_Ast (dtype: numeric)
#     team_TO (dtype: numeric)
#     team_Stl (dtype: numeric)
#     team_Blk (dtype: numeric)
#     team_PF (dtype: numeric)
#     opp_FGM (dtype: numeric)
#     opp_FGA (dtype: numeric)
#     opp_FGM3 (dtype: numeric)
#     opp_FGA3 (dtype: numeric)
#     opp_FTM (dtype: numeric)
#     opp_FTA (dtype: numeric)
#     opp_OR (dtype: numeric)
#     opp_DR (dtype: numeric)
#     opp_Ast (dtype: numeric)
#     opp_TO (dtype: numeric)
#     opp_Stl (dtype: numeric)
#     opp_Blk (dtype: numeric)
#     opp_PF (dtype: numeric)
#     game_datetime (dtype: datetime_time_index)
#     team_margin (dtype: numeric)
#     team_won (dtype: boolean)
#     game_loc (dtype: categorical)
#     team_season_id (dtype: categorical)
#   Shape:
#     (Rows: 10738, Columns: 39)

# %%
feature_matrix, feature_defs = ft.dfs(entityset=es,
                                      target_entity="team_game_log",
                                      verbose=True
                                     )
# Out:
# Built 41 features
# Elapsed: 00:02 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 11/11 chunks

# %%
from importlib import reload
reload(utils)
#pruned_feature_matrix=utils.remove_low_information_features(feature_matrix)
# Out:
# <module 'utils' from 'C:\\Users\\MatteoHoch\\Documents\\projects\\freelance\\upwork\\feature_labs\\march_madness\\notebooks\\utils.py'>

# %%
# encode categorical values
fm_encoded, features_encoded = ft.encode_features(feature_matrix,
                                                  feature_defs)

print("Number of features %s" % len(features_encoded))
fm_encoded.head(10)
# Out:
# Number of features 77
#                    Season  DayNum  team_TeamID  team_Score  opp_TeamID  \
# team_game_index
# 2016100_1102_1305    2016     100         1102          52        1305
# 2016100_1104_1401    2016     100         1104          63        1401
# 2016100_1110_1131    2016     100         1110          51        1131
# 2016100_1122_1183    2016     100         1122          79        1183
# 2016100_1124_1243    2016     100         1124          82        1243
# 2016100_1125_1240    2016     100         1125          81        1240
# 2016100_1129_1161    2016     100         1129          93        1161
# 2016100_1131_1110    2016     100         1131          71        1110
# 2016100_1133_1260    2016     100         1133          43        1260
# 2016100_1137_1250    2016     100         1137          65        1250
#
#                    opp_Score  NumOT  team_FGM  team_FGA  team_FGM3  team_FGA3  \
# team_game_index
# 2016100_1102_1305         72      0        20        60          3         18
# 2016100_1104_1401         62      0        22        55          8         25
# 2016100_1110_1131         71      0        20        48          3         20
# 2016100_1122_1183         70      0        26        57          4         16
# 2016100_1124_1243         72      0        23        47          7         13
# 2016100_1125_1240         73      0        31        58         12         22
# 2016100_1129_1161         97      2        29        65         18         35
# 2016100_1131_1110         51      0        22        42          8         14
# 2016100_1133_1260         54      0        17        58          3         20
# 2016100_1137_1250         80      0        23        55          6         21
#
#                    team_FTM  team_FTA  team_OR  team_DR  team_Ast  team_TO  \
# team_game_index
# 2016100_1102_1305         9        15       13       15         8        9
# 2016100_1104_1401        11        16       14       22        10       13
# 2016100_1110_1131         8         9        5       15        12       16
# 2016100_1122_1183        23        30       15       27        15       11
# 2016100_1124_1243        29        30        6       19        16       15
# 2016100_1125_1240         7        14       11       21        21       10
# 2016100_1129_1161        17        22        4       30        18       11
# 2016100_1131_1110        19        23        7       23        12       18
# 2016100_1133_1260         6        17       15       32        10       14
# 2016100_1137_1250        13        18        8       26        14       18
#
#                    team_Stl  team_Blk  team_PF  opp_FGM  opp_FGA  opp_FGM3  \
# team_game_index
# 2016100_1102_1305         6         3       17       25       48         5
# 2016100_1104_1401        12         3       21       19       45         8
# 2016100_1110_1131         6         1       17       22       42         8
# 2016100_1122_1183         6         2       11       27       62         9
# 2016100_1124_1243         8         6       19       25       64         2
# 2016100_1125_1240         5         1       17       25       46         8
# 2016100_1129_1161         8         2       30       28       66        11
# 2016100_1131_1110         9         2       13       20       48         3
# 2016100_1133_1260         4         1       20       19       51         3
# 2016100_1137_1250         3         5       19       30       57         7
#
#                    opp_FGA3  opp_FTM  opp_FTA  opp_OR  opp_DR  opp_Ast  \
# team_game_index
# 2016100_1102_1305                           0                           0
# 2016100_1104_1401                           0                           0
# 2016100_1110_1131                           0                           0
# 2016100_1122_1183                           0                           0
# 2016100_1124_1243                           0                           0
# 2016100_1125_1240                           0                           0
# 2016100_1129_1161                           0                           0
# 2016100_1131_1110                           0                           0
# 2016100_1133_1260                           0                           0
# 2016100_1137_1250                           0                           0
#
#                    WEEKDAY(game_datetime) = 3  \
# team_game_index
# 2016100_1102_1305                           0
# 2016100_1104_1401                           0
# 2016100_1110_1131                           0
# 2016100_1122_1183                           0
# 2016100_1124_1243                           0
# 2016100_1125_1240                           0
# 2016100_1129_1161                           0
# 2016100_1131_1110                           0
# 2016100_1133_1260                           0
# 2016100_1137_1250                           0
#
#                    WEEKDAY(game_datetime) is unknown
# team_game_index
# 2016100_1102_1305                                  0
# 2016100_1104_1401                                  0
# 2016100_1110_1131                                  0
# 2016100_1122_1183                                  0
# 2016100_1124_1243                                  0
# 2016100_1125_1240                                  0
# 2016100_1129_1161                                  0
# 2016100_1131_1110                                  0
# 2016100_1133_1260                                  0
# 2016100_1137_1250                                  0

# %%
y=fm_encoded['team_won']
for col in cols:
    if col in fm_encoded:
        fm_encoded=fm_encoded.drop([col],axis=1)
X=fm_encoded.fillna(0)

# %%
from sklearn.ensemble import *
from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators=400, n_jobs=-1)
scores = cross_val_score(estimator=clf,X=X, y=y, cv=3,
                         scoring="roc_auc", verbose=True)

"AUC %.2f +/- %.2f" % (scores.mean(), scores.std())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   11.5s finished
# 'AUC 0.69 +/- 0.02'

# %%
import utils

clf.fit(X, y)
utils.feature_importances(clf, features_encoded, n=300)
# Out:
# 1: Feature: Season, 0.052
# 2: Feature: DayNum, 0.048
# 3: Feature: opp_TO, 0.046
# 4: Feature: opp_Ast, 0.045
# 5: Feature: team_won, 0.042
# 6: Feature: opp_FTA, 0.041
# 7: Feature: opp_Stl, 0.036
# 8: Feature: opp_Blk, 0.035
# 9: Feature: game_loc = H, 0.031
# 10: Feature: game_loc = A, 0.030
# 11: Feature: team_season_id = 2016_1290, 0.024
# 12: Feature: team_season_id = 2016_1330, 0.023
# 13: Feature: game_loc = N, 0.022
# 14: Feature: game_loc is unknown, 0.022
# 15: Feature: team_Ast, 0.020
# 16: Feature: team_TO, 0.019
# 17: Feature: opp_PF, 0.019
# 18: Feature: team_Stl, 0.017
# 19: Feature: opp_FGA, 0.017
# 20: Feature: team_Blk, 0.016
# 21: Feature: team_TeamID, 0.016
# 22: Feature: opp_FGM, 0.016
# 23: Feature: opp_FGA3, 0.016
# 24: Feature: opp_FTM, 0.015
# 25: Feature: team_PF, 0.015
# 26: Feature: opp_FGM3, 0.013
# 27: Feature: DAY(game_datetime) = 23, 0.005
# 28: Feature: YEAR(game_datetime) is unknown, 0.005
# 29: Feature: WEEKDAY(game_datetime) = 2, 0.004
# 30: Feature: WEEKDAY(game_datetime) = 0, 0.004
# 31: Feature: DAY(game_datetime) = 16, 0.003
# 32: Feature: DAY(game_datetime) = 30, 0.002
# 33: Feature: DAY(game_datetime) is unknown, 0.002
# 34: Feature: MONTH(game_datetime) = 2, 0.001
# 35: Feature: WEEKDAY(game_datetime) = 4, 0.001
# 36: Feature: MONTH(game_datetime) = 5, 0.001
# 37: Feature: WEEKDAY(game_datetime) = 3, 0.001
# 38: Feature: MONTH(game_datetime) = 3, 0.001
# 39: Feature: WEEKDAY(game_datetime) is unknown, 0.001
# 40: Feature: WEEKDAY(game_datetime) = 5, 0.001
# 41: Feature: MONTH(game_datetime) = 4, 0.001
# 42: Feature: WEEKDAY(game_datetime) = 6, 0.001
# 43: Feature: MONTH(game_datetime) is unknown, 0.001
# 44: Feature: MONTH(game_datetime) = 1, 0.001
# 45: Feature: team_season_id = 2016_1433, 0.001
# 46: Feature: DAY(game_datetime) = 4, 0.001
# 47: Feature: WEEKDAY(game_datetime) = 1, 0.001
# 48: Feature: DAY(game_datetime) = 9, 0.001
# 49: Feature: YEAR(game_datetime) = 2016, 0.001
# 50: Feature: DAY(game_datetime) = 13, 0.000
# 51: Feature: DAY(game_datetime) = 27, 0.000
# 52: Feature: team_season_id = 2016_1397, 0.000
# 53: Feature: team_season_id = 2016_1386, 0.000
# 54: Feature: team_season_id = 2016_1408, 0.000
# 55: Feature: DAY(game_datetime) = 2, 0.000
# 56: Feature: team_season_id = 2016_1345, 0.000
# 57: Feature: team_season_id is unknown, 0.000
# 58: Feature: DAY(game_datetime) = 20, 0.000
# 59: Feature: DAY(game_datetime) = 6, 0.000
# 60: Feature: team_season_id = 2016_1401, 0.000
# 61: Feature: team_DR, 0.000
# 62: Feature: team_FTA, 0.000
# 63: Feature: team_FGM3, 0.000
# 64: Feature: NumOT, 0.000
# 65: Feature: team_FTM, 0.000
# 66: Feature: opp_Score, 0.000
# 67: Feature: team_FGA3, 0.000
# 68: Feature: team_FGA, 0.000
# 69: Feature: team_FGM, 0.000
# 70: Feature: opp_TeamID, 0.000
# 71: Feature: team_Score, 0.000
# 72: Feature: team_OR, 0.000
# 73: Feature: opp_OR, 0.000
# 74: Feature: opp_DR, 0.000
# 75: Feature: team_margin, 0.000
# 76: Feature: team_season_id = 2016_1452, 0.000
# 77: Feature: team_season_id = 2016_1437, 0.000
# [<Feature: Season>,
#  <Feature: DayNum>,
#  <Feature: opp_TO>,
#  <Feature: opp_Ast>,
#  <Feature: team_won>,
#  <Feature: opp_FTA>,
#  <Feature: opp_Stl>,
#  <Feature: opp_Blk>,
#  <Feature: game_loc = H>,
#  <Feature: game_loc = A>,
#  <Feature: team_season_id = 2016_1290>,
#  <Feature: team_season_id = 2016_1330>,
#  <Feature: game_loc = N>,
#  <Feature: game_loc is unknown>,
#  <Feature: team_Ast>,
#  <Feature: team_TO>,
#  <Feature: opp_PF>,
#  <Feature: team_Stl>,
#  <Feature: opp_FGA>,
#  <Feature: team_Blk>,
#  <Feature: team_TeamID>,
#  <Feature: opp_FGM>,
#  <Feature: opp_FGA3>,
#  <Feature: opp_FTM>,
#  <Feature: team_PF>,
#  <Feature: opp_FGM3>,
#  <Feature: DAY(game_datetime) = 23>,
#  <Feature: YEAR(game_datetime) is unknown>,
#  <Feature: WEEKDAY(game_datetime) = 2>,
#  <Feature: WEEKDAY(game_datetime) = 0>,
#  <Feature: DAY(game_datetime) = 16>,
#  <Feature: DAY(game_datetime) = 30>,
#  <Feature: DAY(game_datetime) is unknown>,
#  <Feature: MONTH(game_datetime) = 2>,
#  <Feature: WEEKDAY(game_datetime) = 4>,
#  <Feature: MONTH(game_datetime) = 5>,
#  <Feature: WEEKDAY(game_datetime) = 3>,
#  <Feature: MONTH(game_datetime) = 3>,
#  <Feature: WEEKDAY(game_datetime) is unknown>,
#  <Feature: WEEKDAY(game_datetime) = 5>,
#  <Feature: MONTH(game_datetime) = 4>,
#  <Feature: WEEKDAY(game_datetime) = 6>,
#  <Feature: MONTH(game_datetime) is unknown>,
#  <Feature: MONTH(game_datetime) = 1>,
#  <Feature: team_season_id = 2016_1433>,
#  <Feature: DAY(game_datetime) = 4>,
#  <Feature: WEEKDAY(game_datetime) = 1>,
#  <Feature: DAY(game_datetime) = 9>,
#  <Feature: YEAR(game_datetime) = 2016>,
#  <Feature: DAY(game_datetime) = 13>,
#  <Feature: DAY(game_datetime) = 27>,
#  <Feature: team_season_id = 2016_1397>,
#  <Feature: team_season_id = 2016_1386>,
#  <Feature: team_season_id = 2016_1408>,
#  <Feature: DAY(game_datetime) = 2>,
#  <Feature: team_season_id = 2016_1345>,
#  <Feature: team_season_id is unknown>,
#  <Feature: DAY(game_datetime) = 20>,
#  <Feature: DAY(game_datetime) = 6>,
#  <Feature: team_season_id = 2016_1401>,
#  <Feature: team_DR>,
#  <Feature: team_FTA>,
#  <Feature: team_FGM3>,
#  <Feature: NumOT>,
#  <Feature: team_FTM>,
#  <Feature: opp_Score>,
#  <Feature: team_FGA3>,
#  <Feature: team_FGA>,
#  <Feature: team_FGM>,
#  <Feature: opp_TeamID>,
#  <Feature: team_Score>,
#  <Feature: team_OR>,
#  <Feature: opp_OR>,
#  <Feature: opp_DR>,
#  <Feature: team_margin>,
#  <Feature: team_season_id = 2016_1452>,
#  <Feature: team_season_id = 2016_1437>]

# %%
lr = LogisticRegression()
model = lr.fit(X, y)
model.score(X, y)
# Out:
# C:\Users\MatteoHoch\Anaconda3\envs\march_madness\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.6967777984727137

# %% [markdown]
# # FT Ideas
# - Seasonal data?  Will the "Training window" work? https://docs.featuretools.com/automated_feature_engineering/handling_time.html#training-window-and-the-last-time-index
# - Compound key?
# - win record? should I try to prep data so FT will create it and the derived fields like last 10 games? Or code manually?
# - oppositional data? In the past I've done home_team, home_opp, away_team,away_opp (team and opp loosely correspond to OFF and DEF).

# %% [markdown]
# # Go Through Tuning
# https://docs.featuretools.com/guides/tuning_dfs.html
# conferences are "interesting_values"
# go deeper into the primitives (can I create a percentage primitive?)

# %% [markdown]
# # Feature Ideas
# Calculate OFF Rating,
# DEF Rating,
# Net rating.
# https://www.kaggle.com/pozz13/ncaa-2k19-eda-zion-s-kingdom shows net_rating_mean as a good feature.
#
# Model games with noise and rankings systems (seeds) as fuzzy. Middle seeds vary a lot in terms of true ranking.
# Non-Elo approach https://www.kaggle.com/raddar/team-power-rankings
# Basketball Advanced Stat Gloassary https://www.basketball-reference.com/about/glossary.html https://www.kaggle.com/bshyammm/starter-kernel-with-model-tune-using-fastai
